# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import Normalizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### Test recommandations system (collaborative filtering : user-based)
#
# **Source**<br>
# tutorial: https://medium.com/grabngoinfo/recommendation-system-user-based-collaborative-filtering-a2e76e3e15c4<br>
# dataset movie: https://www.kaggle.com/datasets/amirmotefaker/movielens-dataset-movies<br>
# dataset ratings: https://www.kaggle.com/datasets/amirmotefaker/movielens-dataset-for-recommendation-system

# %%
df_movie = pd.read_csv('movies.csv')
df_ratings = pd.read_csv('ratings.csv')

# %% [markdown]
# #### Datasets analysis

# %%
df_movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_movie.shape
# Out:
# (10329, 3)

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       16     4.0  1217897793
# 1       1       24     1.5  1217895807
# 2       1       32     4.0  1217896246
# 3       1       47     4.0  1217896556
# 4       1       50     4.0  1217896523

# %%
df_ratings.shape
# Out:
# (105339, 4)

# %%
df_ratings['userId'].nunique()
# Out:
# 668

# %%
df_movie['movieId'].nunique()
# Out:
# 10329

# %%
#merge df_ratings and df_movie

# %% [markdown]
# ### Datasets join

# %% [markdown]
# **merge df_ratings and df_movie to make one dataset**

# %%
df = pd.merge(df_ratings, df_movie, on='movieId', how='inner')

# %%
df.head()
# Out:
#    userId  movieId  rating   timestamp          title       genres
# 0       1       16     4.0  1217897793  Casino (1995)  Crime|Drama
# 1       9       16     4.0   842686699  Casino (1995)  Crime|Drama
# 2      12       16     1.5  1144396284  Casino (1995)  Crime|Drama
# 3      24       16     4.0   963468757  Casino (1995)  Crime|Drama
# 4      29       16     3.0   836820223  Casino (1995)  Crime|Drama

# %% [markdown]
# **filtering movies under 100 ratings**

# %% [markdown]
# We filter all the movie under 100 ratings to avoid that the score is not representative of the movie quality

# %%
nb_ratings = pd.pivot_table(df, 
                            values=['rating'],
                            index=['movieId'],
                            aggfunc = 'count'
                           )
nb_ratings.head()
# Out:
#          rating
# movieId
# 1           232
# 2            92
# 3            58
# 4            11
# 5            62

# %%
nb_ratings.reset_index(inplace = True)

# %%
nb_ratings = nb_ratings.loc[nb_ratings['rating'] > 100]

# %%
nb_ratings.shape
# Out:
# (150, 2)

# %%
df_result = df.loc[df['movieId'].isin(nb_ratings['movieId'])]

# %%
df_result.shape
# Out:
# (22556, 6)

# %%
df_result.head()
# Out:
#      userId  movieId  rating   timestamp  \
# 122       1       32     4.0  1217896246
# 123       2       32     3.0   859046895
# 124       4       32     5.0   950323750
# 125       7       32     5.0  1322058768
# 126       8       32     3.0   858610933
#
#                                          title                   genres
# 122  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller
# 123  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller
# 124  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller
# 125  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller
# 126  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller

# %% [markdown]
# #### Creation of user based matrix
#
# We make a pivot table with the user in index, the movie in columns and the ratings in values.<br>
# This matrix constitute an important step in the elaboration of the recommandations system

# %%
matrix = pd.pivot_table(df_result, 
                        values = ['rating'],
                        index = ['userId'],
                        columns = ['title'],
                        #fill_value = 0
                       )
matrix
# Out:
#                              rating                                    \
# title  2001: A Space Odyssey (1968) Ace Ventura: Pet Detective (1994)
# userId
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# 5                               NaN                               1.0
# ...                             ...                               ...
# 664                             NaN                               NaN
# 665                             NaN                               3.0
# 666                             NaN                               NaN
# 667                             NaN                               3.5
# 668                             3.0                               NaN
#
#                                                   \
# title  Aladdin (1992) Alien (1979) Aliens (1986)
# userId
# 1                 NaN          NaN           NaN
# 2                 NaN          NaN           NaN
# 3                 3.0          NaN           NaN
# 4                 NaN          NaN           NaN
# 5                 3.5          NaN           NaN
# ...               ...          ...           ...
# 664               NaN          2.0           NaN
# 665               NaN          NaN           NaN
# 666               NaN          4.0           NaN
# 667               NaN          NaN           NaN
# 668               3.0          4.0           3.5
#
#                                                              \
# title  Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)
# userId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# ...                                                   ...
# 664                                                   NaN
# 665                                                   4.5
# 666                                                   NaN
# 667                                                   4.5
# 668                                                   2.5
#
#                                                                              \
# title  American Beauty (1999) American History X (1998) American Pie (1999)
# userId
# 1                         4.0                       NaN                 NaN
# 2                         NaN                       NaN                 NaN
# 3                         NaN                       NaN                 NaN
# 4                         NaN                       NaN                 NaN
# 5                         NaN                       NaN                 NaN
# ...                       ...                       ...                 ...
# 664                       NaN                       NaN                 NaN
# 665                       NaN                       NaN                 NaN
# 666                       4.0                       NaN                 2.0
# 667                       4.5                       NaN                 NaN
# 668                       4.0                       3.0                 2.0
#
#                               ...                          \
# title  Apocalypse Now (1979)  ... Truman Show, The (1998)
# userId                        ...
# 1                        NaN  ...                     NaN
# 2                        NaN  ...                     NaN
# 3                        NaN  ...                     NaN
# 4                        NaN  ...                     NaN
# 5                        NaN  ...                     NaN
# ...                      ...  ...                     ...
# 664                      NaN  ...                     NaN
# 665                      NaN  ...                     NaN
# 666                      4.0  ...                     NaN
# 667                      NaN  ...                     NaN
# 668                      4.0  ...                     3.0
#
#                                                                  \
# title  Twelve Monkeys (a.k.a. 12 Monkeys) (1995) Twister (1996)
# userId
# 1                                            4.0            3.0
# 2                                            3.0            4.0
# 3                                            NaN            3.0
# 4                                            5.0            NaN
# 5                                            NaN            NaN
# ...                                          ...            ...
# 664                                          NaN            NaN
# 665                                          3.5            3.0
# 666                                          NaN            NaN
# 667                                          4.5            NaN
# 668                                          3.0            4.0
#
#                                                      \
# title  Usual Suspects, The (1995) Waterworld (1995)
# userId
# 1                             4.0               NaN
# 2                             NaN               NaN
# 3                             5.0               NaN
# 4                             NaN               NaN
# 5                             NaN               NaN
# ...                           ...               ...
# 664                           NaN               NaN
# 665                           NaN               NaN
# 666                           4.0               NaN
# 667                           4.5               NaN
# 668                           4.0               1.5
#
#                                                                        \
# title  While You Were Sleeping (1995) Who Framed Roger Rabbit? (1988)
# userId
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 3.0                             NaN
# 4                                 NaN                             5.0
# 5                                 NaN                             NaN
# ...                               ...                             ...
# 664                               NaN                             NaN
# 665                               NaN                             NaN
# 666                               NaN                             3.0
# 667                               3.0                             NaN
# 668                               2.0                             2.0
#
#                                                                             \
# title  Willy Wonka & the Chocolate Factory (1971) Wizard of Oz, The (1939)
# userId
# 1                                             NaN                      NaN
# 2                                             4.0                      NaN
# 3                                             NaN                      NaN
# 4                                             NaN                      5.0
# 5                                             NaN                      NaN
# ...                                           ...                      ...
# 664                                           NaN                      NaN
# 665                                           4.0                      NaN
# 666                                           NaN                      3.0
# 667                                           NaN                      NaN
# 668                                           NaN                      5.0
#
#
# title  X-Men (2000)
# userId
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# ...             ...
# 664             NaN
# 665             NaN
# 666             4.0
# 667             NaN
# 668             3.0
#
# [653 rows x 150 columns]

# %% [markdown]
# ### Normalization
#
# We normalize the data on the mean to improve the model performance.

# %%
matrix_norm = matrix.subtract(matrix.mean(axis=1), axis = 0)
matrix_norm.head()
# Out:
#                              rating                                    \
# title  2001: A Space Odyssey (1968) Ace Ventura: Pet Detective (1994)
# userId
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# 5                               NaN                              -1.7
#
#                                                   \
# title  Aladdin (1992) Alien (1979) Aliens (1986)
# userId
# 1                 NaN          NaN           NaN
# 2                 NaN          NaN           NaN
# 3           -0.714286          NaN           NaN
# 4                 NaN          NaN           NaN
# 5            0.800000          NaN           NaN
#
#                                                              \
# title  Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)
# userId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
#
#                                                                              \
# title  American Beauty (1999) American History X (1998) American Pie (1999)
# userId
# 1                    0.169231                       NaN                 NaN
# 2                         NaN                       NaN                 NaN
# 3                         NaN                       NaN                 NaN
# 4                         NaN                       NaN                 NaN
# 5                         NaN                       NaN                 NaN
#
#                               ...                          \
# title  Apocalypse Now (1979)  ... Truman Show, The (1998)
# userId                        ...
# 1                        NaN  ...                     NaN
# 2                        NaN  ...                     NaN
# 3                        NaN  ...                     NaN
# 4                        NaN  ...                     NaN
# 5                        NaN  ...                     NaN
#
#                                                                  \
# title  Twelve Monkeys (a.k.a. 12 Monkeys) (1995) Twister (1996)
# userId
# 1                                       0.169231      -0.830769
# 2                                      -1.111111      -0.111111
# 3                                            NaN      -0.714286
# 4                                       0.937500            NaN
# 5                                            NaN            NaN
#
#                                                      \
# title  Usual Suspects, The (1995) Waterworld (1995)
# userId
# 1                        0.169231               NaN
# 2                             NaN               NaN
# 3                        1.285714               NaN
# 4                             NaN               NaN
# 5                             NaN               NaN
#
#                                                                        \
# title  While You Were Sleeping (1995) Who Framed Roger Rabbit? (1988)
# userId
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                           -0.714286                             NaN
# 4                                 NaN                          0.9375
# 5                                 NaN                             NaN
#
#                                                                             \
# title  Willy Wonka & the Chocolate Factory (1971) Wizard of Oz, The (1939)
# userId
# 1                                             NaN                      NaN
# 2                                       -0.111111                      NaN
# 3                                             NaN                      NaN
# 4                                             NaN                   0.9375
# 5                                             NaN                      NaN
#
#
# title  X-Men (2000)
# userId
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
#
# [5 rows x 150 columns]

# %%
matrix_norm.columns = matrix_norm.columns.droplevel()

# %%
matrix_norm.columns
# Out:
# Index(['2001: A Space Odyssey (1968)', 'Ace Ventura: Pet Detective (1994)',
#        'Aladdin (1992)', 'Alien (1979)', 'Aliens (1986)',
#        'Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)',
#        'American Beauty (1999)', 'American History X (1998)',
#        'American Pie (1999)', 'Apocalypse Now (1979)',
#        ...
#        'Truman Show, The (1998)', 'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)',
#        'Twister (1996)', 'Usual Suspects, The (1995)', 'Waterworld (1995)',
#        'While You Were Sleeping (1995)', 'Who Framed Roger Rabbit? (1988)',
#        'Willy Wonka & the Chocolate Factory (1971)',
#        'Wizard of Oz, The (1939)', 'X-Men (2000)'],
#       dtype='object', name='title', length=150)

# %% [markdown]
# #### Creating similiraty matrix with pearson correlation
#
# the correlation matrix is the key to make recommandations to the user based on item similarity

# %%
movie_corr = matrix_norm.T.corr()

# %%
movie_corr
# Out:
# userId       1         2         3         4         5         6         7    \
# userId
# 1       1.000000 -0.306186  0.614559  0.431124 -0.094491  0.471405  0.153463
# 2      -0.306186  1.000000  0.866025 -1.000000       NaN       NaN -0.555556
# 3       0.614559  0.866025  1.000000       NaN  0.162938       NaN -0.228587
# 4       0.431124 -1.000000       NaN  1.000000       NaN       NaN -0.115186
# 5      -0.094491       NaN  0.162938       NaN  1.000000 -0.970725  0.077671
# ...          ...       ...       ...       ...       ...       ...       ...
# 664    -0.505322       NaN -0.491398       NaN -0.548611       NaN -0.271749
# 665     0.029258 -0.174078  0.484123 -0.801784  0.104257 -0.166667  0.002218
# 666     0.018696       NaN  0.336336 -0.063610 -0.944911       NaN  0.213668
# 667     0.144082 -1.000000  0.392989  0.965824 -0.052658  1.000000  0.257518
# 668     0.230468  0.388556  0.231076  0.291551 -0.113529 -0.080930 -0.082118
#
# userId       8         9    10   ...       659       660       661       662  \
# userId                           ...
# 1       0.369274  0.195776 -1.0  ...  0.099066  0.375769  0.107583  0.349334
# 2       0.577350  0.333333  NaN  ... -1.000000       NaN  0.816497 -0.577350
# 3       1.000000  0.391121 -1.0  ...  0.345186  0.585540  1.000000  0.000000
# 4            NaN -0.250000  NaN  ... -0.662266       NaN -1.000000  0.408248
# 5            NaN -0.158114  NaN  ... -0.427828       NaN       NaN  0.960769
# ...          ...       ...  ...  ...       ...       ...       ...       ...
# 664    -0.852803 -0.302708  1.0  ...  0.171191       NaN  0.301511 -0.647150
# 665     0.636364 -0.076847  1.0  ...  0.307814  0.207514       NaN -0.288675
# 666          NaN  0.545545  NaN  ...  0.376376 -1.000000  0.000000 -0.171592
# 667    -0.288675  0.329404  NaN  ...  0.476747 -0.471405 -0.327327 -0.084215
# 668     0.085415  0.171586 -0.5  ...  0.006323  0.856281  0.336910  0.220867
#
# userId       663       664       665       666       667       668
# userId
# 1       0.410803 -0.505322  0.029258  0.018696  0.144082  0.230468
# 2            NaN       NaN -0.174078       NaN -1.000000  0.388556
# 3       0.252050 -0.491398  0.484123  0.336336  0.392989  0.231076
# 4            NaN       NaN -0.801784 -0.063610  0.965824  0.291551
# 5            NaN -0.548611  0.104257 -0.944911 -0.052658 -0.113529
# ...          ...       ...       ...       ...       ...       ...
# 664    -0.090909  1.000000  0.169489 -0.352034 -0.090167 -0.470566
# 665     0.000000  0.169489  1.000000 -0.329502  0.225991  0.247156
# 666    -0.456435 -0.352034 -0.329502  1.000000  0.499537 -0.170243
# 667     0.912871 -0.090167  0.225991  0.499537  1.000000  0.340742
# 668     0.326085 -0.470566  0.247156 -0.170243  0.340742  1.000000
#
# [653 rows x 653 columns]

# %% [markdown]
# #### Creating similarity matrix with cosine

# %%
movie_cos = cosine_similarity(matrix_norm.fillna(0))

# %%
movie_cos
# Out:
# array([[ 1.        , -0.03582951,  0.20601523, ...,  0.02123052,
#          0.04260818,  0.12506527],
#        [-0.03582951,  1.        ,  0.1523258 , ...,  0.07311028,
#         -0.07814087,  0.07738403],
#        [ 0.20601523,  0.1523258 ,  1.        , ...,  0.08228767,
#          0.10688984,  0.10399275],
#        ...,
#        [ 0.02123052,  0.07311028,  0.08228767, ...,  1.        ,
#          0.14654264, -0.0928286 ],
#        [ 0.04260818, -0.07814087,  0.10688984, ...,  0.14654264,
#          1.        ,  0.1431604 ],
#        [ 0.12506527,  0.07738403,  0.10399275, ..., -0.0928286 ,
#          0.1431604 ,  1.        ]])

# %%
movie_cos = pd.DataFrame(movie_cos, columns = matrix_norm.index, index = matrix_norm.index)

# %%
movie_cos
# Out:
# userId       1         2         3         4         5         6         7    \
# userId
# 1       1.000000 -0.035830  0.206015  0.079337 -0.011293  0.058817  0.074279
# 2      -0.035830  1.000000  0.152326 -0.148343  0.107229 -0.017177 -0.083182
# 3       0.206015  0.152326  1.000000 -0.012940  0.028421 -0.021129 -0.059749
# 4       0.079337 -0.148343 -0.012940  1.000000 -0.144293 -0.029302 -0.042817
# 5      -0.011293  0.107229  0.028421 -0.144293  1.000000 -0.108723  0.025429
# ...          ...       ...       ...       ...       ...       ...       ...
# 664    -0.148462  0.009350 -0.108868  0.004669 -0.079261  0.234327 -0.069455
# 665     0.016409  0.024708  0.123886 -0.014385  0.177944 -0.036804  0.001241
# 666     0.021231  0.073110  0.082288 -0.031258 -0.061092  0.042912  0.079624
# 667     0.042608 -0.078141  0.106890  0.307073 -0.002459  0.032613  0.148756
# 668     0.125065  0.077384  0.103993  0.106771 -0.043177 -0.021040 -0.046302
#
# userId       8         9         10   ...       659       660       661  \
# userId                                ...
# 1       0.049303  0.049409 -0.010772  ...  0.055534  0.096663  0.026969
# 2       0.372104 -0.012354  0.000000  ...  0.033733  0.000000  0.415301
# 3       0.117897  0.252470 -0.114153  ...  0.092838  0.152893  0.217485
# 4      -0.068126 -0.005428  0.000000  ... -0.007525 -0.002226  0.028577
# 5       0.064838 -0.014903 -0.038633  ... -0.080723 -0.107563 -0.078646
# ...          ...       ...       ...  ...       ...       ...       ...
# 664    -0.115128 -0.093374  0.363611  ...  0.057065  0.132760  0.033976
# 665     0.089642 -0.010714  0.061721  ...  0.176479  0.056386  0.036244
# 666     0.000000  0.150966  0.000000  ...  0.134779  0.026552  0.001787
# 667    -0.042730  0.100180  0.059407  ...  0.237887  0.022152 -0.028656
# 668     0.025478  0.095573 -0.041292  ...  0.003380  0.113660  0.115486
#
# userId       662       663       664       665       666       667       668
# userId
# 1       0.144731  0.126032 -0.148462  0.016409  0.021231  0.042608  0.125065
# 2      -0.158274 -0.139983  0.009350  0.024708  0.073110 -0.078141  0.077384
# 3      -0.049378  0.100799 -0.108868  0.123886  0.082288  0.106890  0.103993
# 4       0.035839 -0.010484  0.004669 -0.014385 -0.031258  0.307073  0.106771
# 5       0.081995 -0.019957 -0.079261  0.177944 -0.061092 -0.002459 -0.043177
# ...          ...       ...       ...       ...       ...       ...       ...
# 664    -0.152960 -0.006644  1.000000  0.085020 -0.070976 -0.008447 -0.175570
# 665    -0.036913  0.136117  0.085020  1.000000 -0.131240  0.099001  0.100273
# 666    -0.064813 -0.045730 -0.070976 -0.131240  1.000000  0.146543 -0.092829
# 667     0.011656  0.245504 -0.008447  0.099001  0.146543  1.000000  0.143160
# 668     0.122168  0.075476 -0.175570  0.100273 -0.092829  0.143160  1.000000
#
# [653 rows x 653 columns]

# %% [markdown]
# ### Example of ratings prediction for 1 user

# %%
n = 10

user = 1
user_sim = movie_corr
user_sim = user_sim[user].loc[user_sim.index != user].sort_values(ascending = False)[:n]

user_sim
# Out:
# userId
# 533    1.000000
# 34     1.000000
# 67     1.000000
# 154    1.000000
# 117    1.000000
# 621    0.981981
# 526    0.966988
# 103    0.945343
# 271    0.943300
# 26     0.940582
# Name: 1, dtype: float64

# %%
watched_movie = matrix_norm.loc[matrix_norm.index == user].dropna(
                                                            axis = 1,
                                                            how = 'all'
                                                            )
watched_movie
# Out:
# title   American Beauty (1999)  Apollo 13 (1995)  Back to the Future (1985)  \
# userId
# 1                     0.169231         -0.830769                  -0.830769
#
# title   Batman (1989)  Batman Begins (2005)  Beautiful Mind, A (2001)  \
# userId
# 1           -1.330769              0.669231                  0.169231
#
# title   Bourne Identity, The (2002)  Braveheart (1995)  Casablanca (1942)  \
# userId
# 1                          0.169231           0.169231           1.169231
#
# title   Clear and Present Danger (1994)  ...  \
# userId                                   ...
# 1                              0.669231  ...
#
# title   Star Wars: Episode IV - A New Hope (1977)  \
# userId
# 1                                        0.669231
#
# title   Star Wars: Episode V - The Empire Strikes Back (1980)  \
# userId
# 1                                                0.669231
#
# title   Star Wars: Episode VI - Return of the Jedi (1983)  \
# userId
# 1                                                0.669231
#
# title   Terminator 2: Judgment Day (1991)  \
# userId
# 1                               -0.330769
#
# title   There's Something About Mary (1998)  Titanic (1997)  True Lies (1994)  \
# userId
# 1                                 -2.330769       -2.330769         -0.830769
#
# title   Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Twister (1996)  \
# userId
# 1                                        0.169231       -0.830769
#
# title   Usual Suspects, The (1995)
# userId
# 1                         0.169231
#
# [1 rows x 65 columns]

# %%
watched_sim = matrix_norm.loc[matrix_norm.index.isin(user_sim.index)]\
                .dropna(axis = 1, how = 'all')\
                .drop(watched_movie.columns, axis = 1, errors = 'ignore')


watched_sim
# Out:
# title   American Pie (1999)  Austin Powers: The Spy Who Shagged Me (1999)  \
# userId
# 26                      NaN                                     -0.416667
# 34                      NaN                                           NaN
# 67                      NaN                                     -0.625000
# 103                     NaN                                           NaN
# 117                     NaN                                           NaN
# 154                     NaN                                           NaN
# 271                     NaN                                           NaN
# 526                     0.4                                      0.400000
# 533                     NaN                                           NaN
# 621                     NaN                                           NaN
#
# title   Being John Malkovich (1999)  Breakfast Club, The (1985)  \
# userId
# 26                         1.083333                         NaN
# 34                              NaN                         NaN
# 67                        -0.125000                      -0.625
# 103                             NaN                         NaN
# 117                             NaN                         NaN
# 154                             NaN                         NaN
# 271                             NaN                         NaN
# 526                             NaN                         NaN
# 533                             NaN                         NaN
# 621                             NaN                         NaN
#
# title   Broken Arrow (1996)  Bug's Life, A (1998)  \
# userId
# 26                      NaN                   NaN
# 34                      NaN                   NaN
# 67                      NaN                   NaN
# 103                     NaN                   NaN
# 117                    -1.0                   NaN
# 154                     NaN                   NaN
# 271                    -1.0                   NaN
# 526                    -0.6                  -0.6
# 533                     NaN                   NaN
# 621                     NaN                   NaN
#
# title   Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)  \
# userId
# 26                                                    NaN
# 34                                                  0.400
# 67                                                  0.875
# 103                                                   NaN
# 117                                                   NaN
# 154                                                   NaN
# 271                                                   NaN
# 526                                                   NaN
# 533                                                   NaN
# 621                                                   NaN
#
# title   E.T. the Extra-Terrestrial (1982)  Ferris Bueller's Day Off (1986)  \
# userId
# 26                                    NaN                              NaN
# 34                                    NaN                              NaN
# 67                                    NaN                              NaN
# 103                                 0.125                              NaN
# 117                                   NaN                              NaN
# 154                                   NaN                              NaN
# 271                                   NaN                              NaN
# 526                                   NaN                              0.4
# 533                                   NaN                              0.0
# 621                                   NaN                              NaN
#
# title   Fifth Element, The (1997)  ...  Hunt for Red October, The (1990)  \
# userId                             ...
# 26                      -1.416667  ...                          0.083333
# 34                            NaN  ...                               NaN
# 67                       0.875000  ...                               NaN
# 103                           NaN  ...                               NaN
# 117                           NaN  ...                               NaN
# 154                           NaN  ...                               NaN
# 271                           NaN  ...                               NaN
# 526                           NaN  ...                               NaN
# 533                           NaN  ...                               NaN
# 621                           NaN  ...                               NaN
#
# title   In the Line of Fire (1993)  Kill Bill: Vol. 1 (2003)  Memento (2000)  \
# userId
# 26                       -0.416667                       NaN             NaN
# 34                             NaN                       NaN             NaN
# 67                             NaN                       NaN             NaN
# 103                            NaN                       NaN             NaN
# 117                            NaN                       NaN             NaN
# 154                            NaN                       NaN             NaN
# 271                            NaN                       NaN             NaN
# 526                            NaN                       NaN             NaN
# 533                            NaN                       NaN             NaN
# 621                            NaN                       0.5            -0.5
#
# title   Rock, The (1996)  Total Recall (1990)  Toy Story (1995)  \
# userId
# 26                   NaN                  NaN               NaN
# 34                   NaN                  NaN               NaN
# 67                   NaN                  NaN               NaN
# 103                  NaN               -0.875             0.125
# 117                  0.0                  NaN             0.000
# 154                  NaN                  NaN               NaN
# 271                  0.0                  NaN            -1.000
# 526                  NaN                  NaN               NaN
# 533                  NaN                  NaN               NaN
# 621                  NaN                  NaN               NaN
#
# title   Trainspotting (1996)  Who Framed Roger Rabbit? (1988)  \
# userId
# 26                       NaN                         0.583333
# 34                       NaN                              NaN
# 67                       NaN                              NaN
# 103                      NaN                              NaN
# 117                      NaN                              NaN
# 154                      NaN                              NaN
# 271                     -1.0                              NaN
# 526                      NaN                              NaN
# 533                      NaN                              NaN
# 621                      NaN                              NaN
#
# title   Willy Wonka & the Chocolate Factory (1971)
# userId
# 26                                             NaN
# 34                                             NaN
# 67                                             NaN
# 103                                            NaN
# 117                                           -1.0
# 154                                            NaN
# 271                                            1.0
# 526                                            NaN
# 533                                            NaN
# 621                                            NaN
#
# [10 rows x 23 columns]

# %% [markdown]
# ### Creation of the user based recommandation function

# %%
user = 7
user_sim = movie_corr



def recommandation_user (user,user_sim):
    
    item_score = {}

    user_sim = user_sim[user].loc[user_sim.index != user].sort_values(ascending = False)[:10]

    watched_movie = matrix_norm.loc[matrix_norm.index == user].dropna(
                                                                axis = 1,
                                                                how = 'all'
                                                                )

    watched_sim = matrix_norm.loc[matrix_norm.index.isin(user_sim.index)]\
                    .dropna(axis = 1, how = 'all')\
                    .drop(watched_movie.columns, axis = 1, errors = 'ignore')

    for i in watched_sim.columns:
        rating = watched_sim[i]

        total = 0
        count = 0

        for j in user_sim.index:
            if pd.isna(rating[j]) == False:
                score = user_sim[j]*rating[j]
                total += score
                count += 1
        item_score[i] = total / count

    item_score = pd.DataFrame(item_score.items(), 
                                  columns=['movie', 'movie_score'])

    ranked_item = item_score.sort_values(by='movie_score', 
                                               ascending=False)[:10]

    return ranked_item

# %% [markdown]
# ### test of the user based recommandation function

# %%
recommandation_user (user,user_sim = movie_corr)
# Out:
#                                          movie  movie_score
# 21                  Shakespeare in Love (1998)     1.456088
# 10                                Fargo (1996)     0.947502
# 13                            Gladiator (2000)     0.916667
# 30  Willy Wonka & the Chocolate Factory (1971)     0.857143
# 18                       Monsters, Inc. (2001)     0.747882
# 19      One Flew Over the Cuckoo's Nest (1975)     0.747882
# 29             Who Framed Roger Rabbit? (1988)     0.747882
# 23         There's Something About Mary (1998)     0.666667
# 11                        Fugitive, The (1993)     0.666667
# 27                            True Lies (1994)     0.606703

# %%
recommandation_user (user,user_sim = movie_cos)
# Out:
#                                                 movie  movie_score
# 31         Ghostbusters (a.k.a. Ghost Busters) (1984)     0.327151
# 69         Willy Wonka & the Chocolate Factory (1971)     0.307670
# 62                               Trainspotting (1996)     0.261489
# 2   Amelie (Fabuleux destin d'Amélie Poulain, Le) ...     0.203483
# 15                                  Casablanca (1942)     0.200964
# 33                           Good Will Hunting (1997)     0.184685
# 53                   Shawshank Redemption, The (1994)     0.176790
# 28                               Fugitive, The (1993)     0.158604
# 43                              Lion King, The (1994)     0.156165
# 65                         Usual Suspects, The (1995)     0.137625
